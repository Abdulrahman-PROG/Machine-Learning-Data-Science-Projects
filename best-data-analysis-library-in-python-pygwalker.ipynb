# %% [markdown]
# ## Imagine you have a bunch of data in Jupyter Notebook that you want to analyze and visualize. PyGWalker is like a magic tool that makes it super easy for you. It takes your data and turns it into a special kind of table that you can interact with, just like using Tableau. You can explore your data visually, play around with it, and see patterns and insights without getting lost in complicated code. PyGWalker simplifies everything, so you can analyze and understand your data quickly and effortlessly. PyGWalker, developed by Kanaries.

# %% [markdown]
# # Install PyGWalker library via pip

# %%
# !pip install pygwalker -q

# %%
import pandas as pd
import pygwalker as pyg
# Out:
#         <p>Since you haven't set the kannaries_api_key, Pygwalker assumes it's your first time using it on Kaggle.</p>
#         <p>Due to the persistent file approach in Kaggle, there may be some impact on the user experience when using Pygwalker on Kaggle.</p>
#         <p>Please take a moment to read this article: <a href="https://github.com/Kanaries/pygwalker/wiki/Best-Practices-for-Using-Pygwalker-in-Kaggle">Best Practices for Using Pygwalker in Kaggle</a>, which can help you optimize your Pygwalker experience on Kaggle.</p>

# %% [markdown]
# ## The “import pandas as pd” line allows you to work with data in a tabular format, while “import pygwalker as pyg” brings in the PyGWalker library.
#
# Once imported, you can seamlessly integrate PyGWalker into your existing workflow.
#
# For instance, you can load your data using pandas

# %%
df = pd.read_csv('/kaggle/input/insurance/insurance.csv')

# %% [markdown]
# # Then, you can create an instance of PyGWalker, named “gwalker,” by passing your dataframe as an argument, such as:

# %%
gwalker = pyg.walk(df)
# Out:
# Box(children=(HTML(value='<div id="ifr-pyg-00060d19ae4b019730clBJUgGWI6t7LD" style="height: auto">\n    <head>…

# %% [markdown]
# ### This interface offers various drag and drop features that you can utilize to analyze and explore your data. It provides a convenient and interactive way to interact with your data, enabling you to perform tasks like visualizing data, exploring relationships.
#
# ### With PyGWalker, you now have a user interface similar to Tableau that allows you to analyze and visualize your data

# %%
pyg.walk(df,hideDataSourceConfig=True,vegaTheme='vega')
# Out:
# Box(children=(HTML(value='<div id="ifr-pyg-00060d19c145299cNbuLX4jlHThpyvgQ" style="height: auto">\n    <head>…

# %% [markdown]
# # You can also save the data exploration result to a local file.
#
# PyGWalker is a versatile library that offers numerous functionalities. Exploring this powerful tool can enhance your skills in data analysis and visualization. If you have any questions or need assistance, feel free to reach out. Happy exploring with PyGWalker!
